# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tobii_pytracker.analyze.data_loader import DataLoader
from tobii_pytracker.configs.custom_config import CustomConfig

config = CustomConfig('../configs/config.yaml')
loader = DataLoader(config, root='../')

# %%
loader.get_subjects()[-5:]
# Out:
# ['20251104_142931',
#  '20251104_143025',
#  '20251104_144454',
#  '20251104_144523',
#  '20251104_144605']

# %%
loader.get_subject_data(loader.get_subjects()[-1])
# Out:
#                                      screenshot_file  \
# 0  output\20251104_133556\CAM1-20250304 181350293...
#
#                                           input_data classification  \
# 0  datasets/pdt\Discolored\CAM1-20250304 18135029...     discolored
#
#   user_classification                                          gaze_data  \
# 0                exit  [{'angle_x': 0, 'angle_y': 0, 'confidence_inte...
#
#   model_prediction  voice_file  voice_start_timestamp
# 0               []         NaN                    NaN

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).head()
# Out:
#           set_name  slide_index  \
# 0  20251104_133556            0
# 1  20251104_133556            0
# 2  20251104_133556            0
# 3  20251104_133556            0
# 4  20251104_133556            0
#
#                                      screenshot_file  \
# 0  output\20251104_133556\CAM1-20250304 181350293...
# 1  output\20251104_133556\CAM1-20250304 181350293...
# 2  output\20251104_133556\CAM1-20250304 181350293...
# 3  output\20251104_133556\CAM1-20250304 181350293...
# 4  output\20251104_133556\CAM1-20250304 181350293...
#
#                                           input_data classification  \
# 0  datasets/pdt\Discolored\CAM1-20250304 18135029...     discolored
# 1  datasets/pdt\Discolored\CAM1-20250304 18135029...     discolored
# 2  datasets/pdt\Discolored\CAM1-20250304 18135029...     discolored
# 3  datasets/pdt\Discolored\CAM1-20250304 18135029...     discolored
# 4  datasets/pdt\Discolored\CAM1-20250304 18135029...     discolored
#
#   user_classification model_prediction  voice_file  voice_start_timestamp  \
# 0                exit               []         NaN                    NaN
# 1                exit               []         NaN                    NaN
# 2                exit               []         NaN                    NaN
# 3                exit               []         NaN                    NaN
# 4                exit               []         NaN                    NaN
#
#                   event_type  ...  system_time  gaze_x_left  gaze_y_left  \
# 0       FixationStartEventNT  ...    14.276661         None         None
# 1  MonocularEyeSampleEventNT  ...    14.276661         None         None
# 2  MonocularEyeSampleEventNT  ...    14.276661         None         None
# 3  MonocularEyeSampleEventNT  ...    14.276661         None         None
# 4  MonocularEyeSampleEventNT  ...    14.276661         None         None
#
#   gaze_x_right gaze_y_right pupil_left pupil_right avg_gaze_x avg_gaze_y  \
# 0         None         None       None        None       None       None
# 1         None         None       None        None       None       None
# 2         None         None       None        None       None       None
# 3         None         None       None        None       None       None
# 4         None         None       None        None       None       None
#
#   avg_pupil_size
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
#
# [5 rows x 22 columns]

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).tail()
# Out:
#             set_name  slide_index  \
# 328  20251104_133556            0
# 329  20251104_133556            0
# 330  20251104_133556            0
# 331  20251104_133556            0
# 332  20251104_133556            0
#
#                                        screenshot_file  \
# 328  output\20251104_133556\CAM1-20250304 181350293...
# 329  output\20251104_133556\CAM1-20250304 181350293...
# 330  output\20251104_133556\CAM1-20250304 181350293...
# 331  output\20251104_133556\CAM1-20250304 181350293...
# 332  output\20251104_133556\CAM1-20250304 181350293...
#
#                                             input_data classification  \
# 328  datasets/pdt\Discolored\CAM1-20250304 18135029...     discolored
# 329  datasets/pdt\Discolored\CAM1-20250304 18135029...     discolored
# 330  datasets/pdt\Discolored\CAM1-20250304 18135029...     discolored
# 331  datasets/pdt\Discolored\CAM1-20250304 18135029...     discolored
# 332  datasets/pdt\Discolored\CAM1-20250304 18135029...     discolored
#
#     user_classification model_prediction  voice_file  voice_start_timestamp  \
# 328                exit               []         NaN                    NaN
# 329                exit               []         NaN                    NaN
# 330                exit               []         NaN                    NaN
# 331                exit               []         NaN                    NaN
# 332                exit               []         NaN                    NaN
#
#                     event_type  ...  system_time  gaze_x_left  gaze_y_left  \
# 328  MonocularEyeSampleEventNT  ...    17.526684         None         None
# 329  MonocularEyeSampleEventNT  ...    17.540939         None         None
# 330  MonocularEyeSampleEventNT  ...    17.561958         None         None
# 331  MonocularEyeSampleEventNT  ...    17.595573         None         None
# 332  MonocularEyeSampleEventNT  ...    17.617036         None         None
#
#     gaze_x_right gaze_y_right pupil_left pupil_right avg_gaze_x avg_gaze_y  \
# 328         None         None       None        None       None       None
# 329         None         None       None        None       None       None
# 330         None         None       None        None       None       None
# 331         None         None       None        None       None       None
# 332         None         None       None        None       None       None
#
#     avg_pupil_size
# 328           None
# 329           None
# 330           None
# 331           None
# 332           None
#
# [5 rows x 22 columns]

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).shape
# Out:
# (1241, 22)

# %%
loader.get_subject_data(loader.get_subjects()[-1])['gaze_data'][0]
# Out:
# "[{'angle_x': 0, 'angle_y': 0, 'confidence_interval': 0, 'delay': 0, 'device_id': 0, 'device_time': 11.118682799995877, 'event_id': 3, 'experiment_id': 0, 'eye': 22, 'filter_id': 0, 'gaze_x': 176.0, 'gaze_y': -38.0, 'gaze_z': 0, 'logged_time': 11.118682799995877, 'ppd_x': 0, 'ppd_y': 0, 'pupil_measure1': 5, 'pupil_measure1_type': 77, 'pupil_measure2': 0, 'pupil_measure2_type': 0, 'raw_x': 0, 'raw_y': 0, 'session_id': 0, 'status': 0, 'time': 11.118682799995877, 'type': 53, 'velocity_x': 0, 'velocity_xy': 0, 'velocity_y': 0, 'event_type': 'FixationStartEventNT', 'system_time': 14.276661099982448}, {'angle_x': 0, 'angle_y': 0, 'confidence_interval': 0, 'delay': 0, 'device_id': 0, 'device_time': 11.138682799995877, 'event_id': 4, 'experiment_id': 0, 'eye': 22, 'eye_cam_x': 0, 'eye_cam_y': 0, 'eye_cam_z': 0, 'filter_id': 0, 'gaze_x': 176.0, 'gaze_y': -38.0, 'gaze_z': 0, 'logged_time': 11.138682799995877, 'ppd_x': 0, 'ppd_y': 0, 'pupil_measure1': 5, 'pupil_measure1_type': 77, 'pupil_measure2': 0, 'pupil_measure2_type': 0, 'raw_x': 0, 'raw_y': 0, 'session_id': 0, 'status': 0, 'time': 11.138682799995877, 'type': 51, 'velocity_x': 0, 'velocity_xy': 0, 'velocity_y': 0, 'event_type': 'MonocularEyeSampleEventNT', 'system_time': 14.276661099982448}, {'angle_x': 0, 'angle_y': 0, 'confidence_interval': 0, 'delay': 0, 'device_id': 0, 'device_time': 11.158682799995876, 'event_id': 5, 'experiment_id': 0, 'eye': 22, 'eye_cam_x': 0, 'eye_cam_y': 0, 'eye_cam_z': 0, 'filter_id': 0, 'gaze_x': 176.0, 'gaze_y': -38.0, 'gaze_z': 0, 'logged_time': 11.158682799995876, 'ppd_x': 0, 'ppd_y': 0, 'pupil_measure1': 5, 'pupil_measure1_type': 77, 'pupil_measure2': 0, 'pupil_measure2_type': 0, 'raw_x': 0, 'raw_y': 0, 'session_id': 0, 'status': 0, 'time': 11.158682799995876, 'type': 51, 'velocity_x': 0, 'velocity_xy': 0, 'velocity_y': 0, 'event_type': 'MonocularEyeSampleEventNT', 'system_time': 14.276661099982448}, {'angle_x': 0, 'angle_y': 0, 'confidence_interval': 0, 'delay': 0, 'device_id': 0, 'device_time': 11.178682799995876, 'event_id': 6, 'experiment_id': 0, 'eye': 22, 'eye_cam_x': 0, 'eye_cam_y': 0, 'eye_cam_z': 0, 'filter_id': 0, 'gaze_x': 176.0, 'gaze_y': -38.0, 'gaze_z': 0, 'logged_time': 11.178682799995876, 'ppd_x': 0, 'ppd_y': 0, 'pupil_measure1': 5, 'pupil_measure1_type': 77, 'pupil_measure2': 0, 'pupil_measure2_type': 0, 'raw_x': 0, 'raw_y': 0, 'session_id': 0, 'status': 0, 'time': 11.178682799995876, 'type': 51, 'velocity_x': 0, 'velocity_xy': 0, 'velocity_y': 0, 'event_type': 'MonocularEyeSampleEventNT', 'system_time': 14.276661099982448}, {'angle_x': 0, 'angle_y': 0, 'confidence_interval': 0, 'delay': 0, 'device_id': 0, 'device_time': 11.198682799995876, 'event_id': 7, 'experiment_id': 0, 'eye': 22, 'eye_cam_x': 0, 'eye_cam_y': 0, 'eye_cam_z': 0, 'filter_id': 0, 'gaze_x': 176.0, 'gaze_y': -38.0, 'gaze_z': 0, 'logged_time': 11.198682799995876, 'ppd_x': 0, 'ppd_y': 0, 'pupil_measure1': 5, 'pupil_measure1_type': 77, 'pupil_measure2': 0, 'pupil_measure2_type': 0, 'raw_x': 0, 'raw_y': 0, 'session_id': 0, 'status': 0, 'time': 11.198682799995876, 'type': 51, 'velocity_x': 0, 'velocity_xy': 0, 'velocity_y': 0, 'event_type': 'MonocularEyeSampleEventNT', 'system_time': 14.276661099982448}, {'angle_x': 0, 'angle_y': 0, 'confidence_interval': 0, 'delay': 0, 'device_id': 0, 'device_time': 11.218682799995875, 'event_id': 8, 'experiment_id': 0, 'eye': 22, 'eye_cam_x': 0, 'eye_cam_y': 0, 'eye_cam_z': 0, 'filter_id': 0, 'gaze_x': 176.0, 'gaze_y': -38.0, 'gaze_z': 0, 'logged_time': 11.218682799995875, 'ppd_x': 0, 'ppd_y': 0, 'pupil_measure1': 5, 'pupil_measure1_type': 77, 'pupil_measure2': 0, 'pupil_measure2_type': 0, 'raw_x': 0, 'raw_y': 0, 'session_id': 0, 'status': 0, 'time': 11.218682799995875, 'type': 51, 'velocity_x': 0, 'velocity_xy': 0, 'velocity_y': 0, 'event_type': 'MonocularEyeSampleEventNT', 'system_time': 14.276661099982448}, {'angle_x': 0, 'angle_y': 0, 'confidence_interval': 0, 'delay': 0, 'device_id': 0, 'device_time': 11.238682799995875, 'event_id ...

# %%
loader = DataLoader(config, root='../')
loader.plot_gaze(loader.get_subjects()[-1], 0, gradient=True)
# Out:
# 2025-11-04 15:18:29,865 - matplotlib.colorbar - DEBUG - locator: <matplotlib.ticker.AutoLocator object at 0x000002141EA36320>

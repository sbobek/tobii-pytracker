# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tobii_pytracker.analyze.data_loader import DataLoader
from tobii_pytracker.configs.custom_config import CustomConfig

config = CustomConfig('../configs/config.yaml')
loader = DataLoader(config, root='../')

# %%
loader.get_subjects()[-5:]
# Out:
# ['20251119_125207']

# %%
loader.get_subject_data(loader.get_subjects()[-1])
# Out:
#                                      screenshot_file  \
# 0  output\20251119_125207\CAM1-20250304 181251538...
# 1  output\20251119_125207\CAM4-20250304 181354031...
# 2  output\20251119_125207\CAM2-20250304 181203295...
# 3  output\20251119_125207\CAM1-20250304 181148276...
# 4  output\20251119_125207\CAM2-20250304 181101366...
# 5  output\20251119_125207\CAM2-20250304 181055607...
# 6  output\20251119_125207\CAM2-20250304 181203597...
# 7  output\20251119_125207\CAM3-20250304 181203168...
# 8  output\20251119_125207\CAM2-20250304 181154203...
# 9  output\20251119_125207\CAM1-20250304 181300713...
#
#                                           input_data classification  \
# 0  datasets/pdt\Discolored\CAM1-20250304 18125153...     discolored
# 1   datasets/pdt\Damaged\CAM4-20250304 181354031.bmp        damaged
# 2     datasets/pdt\Dirty\CAM2-20250304 181203295.bmp          dirty
# 3   datasets/pdt\Damaged\CAM1-20250304 181148276.bmp        damaged
# 4     datasets/pdt\Dirty\CAM2-20250304 181101366.bmp          dirty
# 5     datasets/pdt\Dirty\CAM2-20250304 181055607.bmp          dirty
# 6  datasets/pdt\Discolored\CAM2-20250304 18120359...     discolored
# 7  datasets/pdt\Oxidation\CAM3-20250304 181203168...      oxidation
# 8     datasets/pdt\Dirty\CAM2-20250304 181154203.bmp          dirty
# 9  datasets/pdt\Discolored\CAM1-20250304 18130071...     discolored
#
#   user_classification                                          gaze_data  \
# 0          discolored  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 1             damaged  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 2           oxidation  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 3               dirty  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 4               dirty  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 5           oxidation  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 6               dirty  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 7           oxidation  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 8               dirty  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 9          discolored  [{'event_type': 'MonocularEyeSampleEventNT', '...
#
#          objects_bboxes  voice_file  voice_start_timestamp
# 0  {'image_bboxes': []}         NaN                    NaN
# 1  {'image_bboxes': []}         NaN                    NaN
# 2  {'image_bboxes': []}         NaN                    NaN
# 3  {'image_bboxes': []}         NaN                    NaN
# 4  {'image_bboxes': []}         NaN                    NaN
# 5  {'image_bboxes': []}         NaN                    NaN
# 6  {'image_bboxes': []}         NaN                    NaN
# 7  {'image_bboxes': []}         NaN                    NaN
# 8  {'image_bboxes': []}         NaN                    NaN
# 9  {'image_bboxes': []}         NaN                    NaN

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).head()
# Out:
#           set_name  slide_index  \
# 0  20251119_125207            0
# 1  20251119_125207            0
# 2  20251119_125207            0
# 3  20251119_125207            0
# 4  20251119_125207            0
#
#                                      screenshot_file  \
# 0  output\20251119_125207\CAM1-20250304 181251538...
# 1  output\20251119_125207\CAM1-20250304 181251538...
# 2  output\20251119_125207\CAM1-20250304 181251538...
# 3  output\20251119_125207\CAM1-20250304 181251538...
# 4  output\20251119_125207\CAM1-20250304 181251538...
#
#                                           input_data classification  \
# 0  datasets/pdt\Discolored\CAM1-20250304 18125153...     discolored
# 1  datasets/pdt\Discolored\CAM1-20250304 18125153...     discolored
# 2  datasets/pdt\Discolored\CAM1-20250304 18125153...     discolored
# 3  datasets/pdt\Discolored\CAM1-20250304 18125153...     discolored
# 4  datasets/pdt\Discolored\CAM1-20250304 18125153...     discolored
#
#   user_classification model_prediction  voice_file  voice_start_timestamp  \
# 0          discolored             None         NaN                    NaN
# 1          discolored             None         NaN                    NaN
# 2          discolored             None         NaN                    NaN
# 3          discolored             None         NaN                    NaN
# 4          discolored             None         NaN                    NaN
#
#                   event_type  ...  system_time  gaze_x_left  gaze_y_left  \
# 0  MonocularEyeSampleEventNT  ...     8.503905          2.0          9.0
# 1  MonocularEyeSampleEventNT  ...     8.519407          2.0          9.0
# 2  MonocularEyeSampleEventNT  ...     8.535450          2.0          9.0
# 3  MonocularEyeSampleEventNT  ...     8.551234          2.0          9.0
# 4  MonocularEyeSampleEventNT  ...     8.582339         -2.0          7.0
#
#    gaze_x_right  gaze_y_right pupil_left pupil_right  avg_gaze_x  avg_gaze_y  \
# 0          None          None          5           0         2.0         9.0
# 1          None          None          5           0         2.0         9.0
# 2          None          None          5           0         2.0         9.0
# 3          None          None          5           0         2.0         9.0
# 4          None          None          5           0        -2.0         7.0
#
#    avg_pupil_size
# 0             2.5
# 1             2.5
# 2             2.5
# 3             2.5
# 4             2.5
#
# [5 rows x 22 columns]

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).tail()
# Out:
#             set_name  slide_index  \
# 283  20251119_125207            0
# 284  20251119_125207            0
# 285  20251119_125207            0
# 286  20251119_125207            0
# 287  20251119_125207            0
#
#                                        screenshot_file  \
# 283  output\20251119_125207\CAM1-20250304 181251538...
# 284  output\20251119_125207\CAM1-20250304 181251538...
# 285  output\20251119_125207\CAM1-20250304 181251538...
# 286  output\20251119_125207\CAM1-20250304 181251538...
# 287  output\20251119_125207\CAM1-20250304 181251538...
#
#                                             input_data classification  \
# 283  datasets/pdt\Discolored\CAM1-20250304 18125153...     discolored
# 284  datasets/pdt\Discolored\CAM1-20250304 18125153...     discolored
# 285  datasets/pdt\Discolored\CAM1-20250304 18125153...     discolored
# 286  datasets/pdt\Discolored\CAM1-20250304 18125153...     discolored
# 287  datasets/pdt\Discolored\CAM1-20250304 18125153...     discolored
#
#     user_classification model_prediction  voice_file  voice_start_timestamp  \
# 283          discolored             None         NaN                    NaN
# 284          discolored             None         NaN                    NaN
# 285          discolored             None         NaN                    NaN
# 286          discolored             None         NaN                    NaN
# 287          discolored             None         NaN                    NaN
#
#                     event_type  ...  system_time  gaze_x_left  gaze_y_left  \
# 283  MonocularEyeSampleEventNT  ...    16.716139        235.0         84.0
# 284  MonocularEyeSampleEventNT  ...    16.731655        241.0         87.0
# 285  MonocularEyeSampleEventNT  ...    16.763249        254.0         95.0
# 286  MonocularEyeSampleEventNT  ...    16.778451        261.0         98.0
# 287  MonocularEyeSampleEventNT  ...    16.794691        269.0        102.0
#
#      gaze_x_right  gaze_y_right pupil_left pupil_right  avg_gaze_x  \
# 283          None          None          5           0       235.0
# 284          None          None          5           0       241.0
# 285          None          None          5           0       254.0
# 286          None          None          5           0       261.0
# 287          None          None          5           0       269.0
#
#      avg_gaze_y  avg_pupil_size
# 283        84.0             2.5
# 284        87.0             2.5
# 285        95.0             2.5
# 286        98.0             2.5
# 287       102.0             2.5
#
# [5 rows x 22 columns]

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).shape
# Out:
# (288, 22)

# %%
loader.get_subject_data(loader.get_subjects()[-1])['gaze_data'][0]
# Out:
# "[{'event_type': 'MonocularEyeSampleEventNT', 'event_id': 294, 'logged_time': 8.490061300001027, 'system_time': 8.503905200050212, 'gaze_x_left': 2.0, 'gaze_y_left': 9.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 2.0, 'avg_gaze_y': 9.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 298, 'logged_time': 8.510061300001027, 'system_time': 8.519407400046475, 'gaze_x_left': 2.0, 'gaze_y_left': 9.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 2.0, 'avg_gaze_y': 9.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 299, 'logged_time': 8.530061300001027, 'system_time': 8.535449600080028, 'gaze_x_left': 2.0, 'gaze_y_left': 9.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 2.0, 'avg_gaze_y': 9.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 300, 'logged_time': 8.550061300001026, 'system_time': 8.551234300015494, 'gaze_x_left': 2.0, 'gaze_y_left': 9.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 2.0, 'avg_gaze_y': 9.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 304, 'logged_time': 8.570061300001026, 'system_time': 8.582338800071739, 'gaze_x_left': -2.0, 'gaze_y_left': 7.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -2.0, 'avg_gaze_y': 7.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 305, 'logged_time': 8.590061300001025, 'system_time': 8.600876300013624, 'gaze_x_left': -5.0, 'gaze_y_left': 5.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -5.0, 'avg_gaze_y': 5.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 307, 'logged_time': 8.610061300001025, 'system_time': 8.619759200024419, 'gaze_x_left': -6.0, 'gaze_y_left': 5.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -6.0, 'avg_gaze_y': 5.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 310, 'logged_time': 8.630061300001024, 'system_time': 8.647579800104722, 'gaze_x_left': -7.0, 'gaze_y_left': 4.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -7.0, 'avg_gaze_y': 4.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 327, 'logged_time': 8.83006130000102, 'system_time': 8.840792200062424, 'gaze_x_left': -12.0, 'gaze_y_left': 0.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -12.0, 'avg_gaze_y': 0.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 330, 'logged_time': 8.85006130000102, 'system_time': 8.855139599996619, 'gaze_x_left': -14.0, 'gaze_y_left': -2.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -14.0, 'avg_gaze_y': -2.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 333, 'logged_time': 8.87006130000102, 'system_time': 8.886847200104967, 'gaze_x_left': -16.0, 'gaze_y_left': -3.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -16.0, 'avg_gaze_y': -3.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 334, 'logged_time': 8.890061300001019, 'system_time': 8.90286970010493, 'gaze_x_left': -18.0, 'gaze_y_left': -4.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -18.0, 'avg_gaze_y': -4.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 336, 'logged_time': 8.910061300001018, 'system_time': 8.918556899996474, 'gaze_x_left': -21.0, 'gaze_y_left': -5.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, ' ...

# %%
loader = DataLoader(config, root='../')
loader.plot_gaze(loader.get_subjects()[-1], 0, gradient=True, flip_y=True)

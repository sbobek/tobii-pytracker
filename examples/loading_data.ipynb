# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tobii_pytracker.analyze.data_loader import DataLoader
from tobii_pytracker.configs.custom_config import CustomConfig

config = CustomConfig('../configs/config.yaml')
loader = DataLoader(config, root='../')

# %%
loader.get_subjects()[-5:]
# Out:
# ['20260102_121903',
#  '20260310_094349',
#  '20260310_095339',
#  '20260310_095619',
#  '20260310_100031']

# %%
loader.get_subject_data(loader.get_subjects()[-1])
# Out:
#                          screenshot_file  \
# 0  output\20260310_100031\0.50205548.png
#
#                                           input_data classification  \
# 0  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
#
#   user_classification                                          gaze_data  \
# 0                exit  [{'event_type': 'MonocularEyeSampleEventNT', '...
#
#               objects_bboxes  voice_file  voice_start_timestamp
# 0  {'timeseries_bboxes': []}         NaN                    NaN

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).head()
# Out:
#           set_name  slide_index                        screenshot_file  \
# 0  20260310_100031            0  output\20260310_100031\0.50205548.png
# 1  20260310_100031            0  output\20260310_100031\0.50205548.png
# 2  20260310_100031            0  output\20260310_100031\0.50205548.png
# 3  20260310_100031            0  output\20260310_100031\0.50205548.png
# 4  20260310_100031            0  output\20260310_100031\0.50205548.png
#
#                                           input_data classification  \
# 0  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
# 1  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
# 2  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
# 3  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
# 4  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
#
#   user_classification model_prediction             objects_bboxes  voice_file  \
# 0                exit             None  {'timeseries_bboxes': []}         NaN
# 1                exit             None  {'timeseries_bboxes': []}         NaN
# 2                exit             None  {'timeseries_bboxes': []}         NaN
# 3                exit             None  {'timeseries_bboxes': []}         NaN
# 4                exit             None  {'timeseries_bboxes': []}         NaN
#
#    voice_start_timestamp  ... system_time  gaze_x_left  gaze_y_left  \
# 0                    NaN  ...   17.392260       -318.0         91.0
# 1                    NaN  ...   17.408705       -318.0         91.0
# 2                    NaN  ...   17.424260       -318.0         91.0
# 3                    NaN  ...   17.440523       -318.0         91.0
# 4                    NaN  ...   17.472477       -318.0         91.0
#
#    gaze_x_right  gaze_y_right  pupil_left pupil_right avg_gaze_x  avg_gaze_y  \
# 0          None          None           5           0     -318.0        91.0
# 1          None          None           5           0     -318.0        91.0
# 2          None          None           5           0     -318.0        91.0
# 3          None          None           5           0     -318.0        91.0
# 4          None          None           5           0     -318.0        91.0
#
#    avg_pupil_size
# 0             2.5
# 1             2.5
# 2             2.5
# 3             2.5
# 4             2.5
#
# [5 rows x 23 columns]

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).tail()
# Out:
#             set_name  slide_index                        screenshot_file  \
# 151  20260310_100031            0  output\20260310_100031\0.50205548.png
# 152  20260310_100031            0  output\20260310_100031\0.50205548.png
# 153  20260310_100031            0  output\20260310_100031\0.50205548.png
# 154  20260310_100031            0  output\20260310_100031\0.50205548.png
# 155  20260310_100031            0  output\20260310_100031\0.50205548.png
#
#                                             input_data classification  \
# 151  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
# 152  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
# 153  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
# 154  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
# 155  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
#
#     user_classification model_prediction             objects_bboxes  \
# 151                exit             None  {'timeseries_bboxes': []}
# 152                exit             None  {'timeseries_bboxes': []}
# 153                exit             None  {'timeseries_bboxes': []}
# 154                exit             None  {'timeseries_bboxes': []}
# 155                exit             None  {'timeseries_bboxes': []}
#
#      voice_file  voice_start_timestamp  ... system_time  gaze_x_left  \
# 151         NaN                    NaN  ...   20.414758       -244.0
# 152         NaN                    NaN  ...   20.430616       -244.0
# 153         NaN                    NaN  ...   20.446821       -244.0
# 154         NaN                    NaN  ...   20.463017       -244.0
# 155         NaN                    NaN  ...   20.495509       -243.0
#
#      gaze_y_left  gaze_x_right  gaze_y_right  pupil_left pupil_right  \
# 151        -87.0          None          None           5           0
# 152        -87.0          None          None           5           0
# 153        -87.0          None          None           5           0
# 154        -87.0          None          None           5           0
# 155        -88.0          None          None           5           0
#
#     avg_gaze_x  avg_gaze_y  avg_pupil_size
# 151     -244.0       -87.0             2.5
# 152     -244.0       -87.0             2.5
# 153     -244.0       -87.0             2.5
# 154     -244.0       -87.0             2.5
# 155     -243.0       -88.0             2.5
#
# [5 rows x 23 columns]

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).shape
# Out:
# (156, 23)

# %%
loader.get_subject_data(loader.get_subjects()[-1])['gaze_data'][0]
# Out:
# "[{'event_type': 'MonocularEyeSampleEventNT', 'event_id': 316, 'logged_time': 17.37854240000588, 'system_time': 17.392260499997064, 'gaze_x_left': -318.0, 'gaze_y_left': 91.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -318.0, 'avg_gaze_y': 91.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 321, 'logged_time': 17.39854240000588, 'system_time': 17.408705299996655, 'gaze_x_left': -318.0, 'gaze_y_left': 91.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -318.0, 'avg_gaze_y': 91.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 322, 'logged_time': 17.41854240000588, 'system_time': 17.424260100000538, 'gaze_x_left': -318.0, 'gaze_y_left': 91.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -318.0, 'avg_gaze_y': 91.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 323, 'logged_time': 17.43854240000588, 'system_time': 17.440523099998245, 'gaze_x_left': -318.0, 'gaze_y_left': 91.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -318.0, 'avg_gaze_y': 91.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 324, 'logged_time': 17.45854240000588, 'system_time': 17.472476700000698, 'gaze_x_left': -318.0, 'gaze_y_left': 91.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -318.0, 'avg_gaze_y': 91.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 325, 'logged_time': 17.478542400005878, 'system_time': 17.488092699990375, 'gaze_x_left': -318.0, 'gaze_y_left': 92.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -318.0, 'avg_gaze_y': 92.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 327, 'logged_time': 17.498542400005878, 'system_time': 17.503894599998603, 'gaze_x_left': -318.0, 'gaze_y_left': 99.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -318.0, 'avg_gaze_y': 99.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 333, 'logged_time': 17.518542400005877, 'system_time': 17.53346330000204, 'gaze_x_left': -318.0, 'gaze_y_left': 106.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -318.0, 'avg_gaze_y': 106.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 335, 'logged_time': 17.538542400005877, 'system_time': 17.55077389998769, 'gaze_x_left': -317.0, 'gaze_y_left': 109.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -317.0, 'avg_gaze_y': 109.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 336, 'logged_time': 17.558542400005877, 'system_time': 17.566392499997164, 'gaze_x_left': -317.0, 'gaze_y_left': 115.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -317.0, 'avg_gaze_y': 115.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 338, 'logged_time': 17.578542400005876, 'system_time': 17.581720399990445, 'gaze_x_left': -317.0, 'gaze_y_left': 120.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -317.0, 'avg_gaze_y': 120.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 340, 'logged_time': 17.598542400005876, 'system_time': 17.599020299996482, 'gaze_x_left': -317.0, 'gaze_y_left': 124.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -317.0, 'avg_gaze_y': 124.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 345, 'logged_time': 17.618542400005875, 'system_time': 17.62907319999067, 'gaze_x_left': -317.0, 'g ...

# %%
loader = DataLoader(config, root='../')
loader.plot_gaze(loader.get_subjects()[-1], 0, gradient=True, flip_y=True)

# %%
loader.get_subject_data(loader.get_subjects()[-1])
# Out:
#                          screenshot_file  \
# 0  output\20260310_100031\0.50205548.png
#
#                                           input_data classification  \
# 0  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
#
#   user_classification                                          gaze_data  \
# 0                exit  [{'event_type': 'MonocularEyeSampleEventNT', '...
#
#               objects_bboxes  voice_file  voice_start_timestamp
# 0  {'timeseries_bboxes': []}         NaN                    NaN

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).head().columns
# Out:
# Index(['set_name', 'slide_index', 'screenshot_file', 'input_data',
#        'classification', 'user_classification', 'model_prediction',
#        'objects_bboxes', 'voice_file', 'voice_start_timestamp', 'event_type',
#        'event_id', 'logged_time', 'system_time', 'gaze_x_left', 'gaze_y_left',
#        'gaze_x_right', 'gaze_y_right', 'pupil_left', 'pupil_right',
#        'avg_gaze_x', 'avg_gaze_y', 'avg_pupil_size'],
#       dtype='object')

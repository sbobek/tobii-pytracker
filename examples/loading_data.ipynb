# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tobii_pytracker.analyze.data_loader import DataLoader
from tobii_pytracker.configs.custom_config import CustomConfig

config = CustomConfig('../configs/config.yaml')
loader = DataLoader(config, root='../')

# %%
loader.get_subjects()[-5:]
# Out:
# ['20251105_114523', '20251105_114824']

# %%
loader.get_subject_data(loader.get_subjects()[-1])
# Out:
#                                      screenshot_file  \
# 0  output\20251105_114824\CAM1-20250304 181255060...
#
#                                           input_data classification  \
# 0  datasets/pdt\Discolored\CAM1-20250304 18125506...     discolored
#
#   user_classification                                          gaze_data  \
# 0                exit  [{'event_type': 'MonocularEyeSampleEventNT', '...
#
#   model_prediction  voice_file  voice_start_timestamp  gaze_count  \
# 0               []         NaN                    NaN          84
#
#    focus_intensity
# 0              1.0

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).head()
# Out:
#           set_name  slide_index  \
# 0  20251105_114824            0
# 1  20251105_114824            0
# 2  20251105_114824            0
# 3  20251105_114824            0
# 4  20251105_114824            0
#
#                                      screenshot_file  \
# 0  output\20251105_114824\CAM1-20250304 181255060...
# 1  output\20251105_114824\CAM1-20250304 181255060...
# 2  output\20251105_114824\CAM1-20250304 181255060...
# 3  output\20251105_114824\CAM1-20250304 181255060...
# 4  output\20251105_114824\CAM1-20250304 181255060...
#
#                                           input_data classification  \
# 0  datasets/pdt\Discolored\CAM1-20250304 18125506...     discolored
# 1  datasets/pdt\Discolored\CAM1-20250304 18125506...     discolored
# 2  datasets/pdt\Discolored\CAM1-20250304 18125506...     discolored
# 3  datasets/pdt\Discolored\CAM1-20250304 18125506...     discolored
# 4  datasets/pdt\Discolored\CAM1-20250304 18125506...     discolored
#
#   user_classification model_prediction  voice_file  voice_start_timestamp  \
# 0                exit               []         NaN                    NaN
# 1                exit               []         NaN                    NaN
# 2                exit               []         NaN                    NaN
# 3                exit               []         NaN                    NaN
# 4                exit               []         NaN                    NaN
#
#                   event_type  ...  system_time  gaze_x_left  gaze_y_left  \
# 0  MonocularEyeSampleEventNT  ...     8.381760        113.0        -64.0
# 1  MonocularEyeSampleEventNT  ...     8.413217        114.0        -64.0
# 2  MonocularEyeSampleEventNT  ...     8.429820        116.0        -67.0
# 3  MonocularEyeSampleEventNT  ...     8.446038        119.0        -73.0
# 4  MonocularEyeSampleEventNT  ...     8.461889        128.0        -89.0
#
#    gaze_x_right  gaze_y_right pupil_left pupil_right  avg_gaze_x  avg_gaze_y  \
# 0          None          None          5           0       113.0       -64.0
# 1          None          None          5           0       114.0       -64.0
# 2          None          None          5           0       116.0       -67.0
# 3          None          None          5           0       119.0       -73.0
# 4          None          None          5           0       128.0       -89.0
#
#    avg_pupil_size
# 0             2.5
# 1             2.5
# 2             2.5
# 3             2.5
# 4             2.5
#
# [5 rows x 22 columns]

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).tail()
# Out:
#            set_name  slide_index  \
# 13  20251105_114824            0
# 14  20251105_114824            0
# 15  20251105_114824            0
# 16  20251105_114824            0
# 17  20251105_114824            0
#
#                                       screenshot_file  \
# 13  output\20251105_114824\CAM1-20250304 181255060...
# 14  output\20251105_114824\CAM1-20250304 181255060...
# 15  output\20251105_114824\CAM1-20250304 181255060...
# 16  output\20251105_114824\CAM1-20250304 181255060...
# 17  output\20251105_114824\CAM1-20250304 181255060...
#
#                                            input_data classification  \
# 13  datasets/pdt\Discolored\CAM1-20250304 18125506...     discolored
# 14  datasets/pdt\Discolored\CAM1-20250304 18125506...     discolored
# 15  datasets/pdt\Discolored\CAM1-20250304 18125506...     discolored
# 16  datasets/pdt\Discolored\CAM1-20250304 18125506...     discolored
# 17  datasets/pdt\Discolored\CAM1-20250304 18125506...     discolored
#
#    user_classification model_prediction  voice_file  voice_start_timestamp  \
# 13                exit               []         NaN                    NaN
# 14                exit               []         NaN                    NaN
# 15                exit               []         NaN                    NaN
# 16                exit               []         NaN                    NaN
# 17                exit               []         NaN                    NaN
#
#                    event_type  ...  system_time  gaze_x_left  gaze_y_left  \
# 13  MonocularEyeSampleEventNT  ...     8.901543        154.0       -206.0
# 14  MonocularEyeSampleEventNT  ...     8.933796        156.0       -203.0
# 15  MonocularEyeSampleEventNT  ...     8.949537        175.0       -183.0
# 16  MonocularEyeSampleEventNT  ...     8.966130        184.0       -172.0
# 17  MonocularEyeSampleEventNT  ...     8.981768        206.0       -150.0
#
#     gaze_x_right  gaze_y_right pupil_left pupil_right  avg_gaze_x  avg_gaze_y  \
# 13          None          None          5           0       154.0      -206.0
# 14          None          None          5           0       156.0      -203.0
# 15          None          None          5           0       175.0      -183.0
# 16          None          None          5           0       184.0      -172.0
# 17          None          None          5           0       206.0      -150.0
#
#     avg_pupil_size
# 13             2.5
# 14             2.5
# 15             2.5
# 16             2.5
# 17             2.5
#
# [5 rows x 22 columns]

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).shape
# Out:
# (18, 22)

# %%
loader.get_subject_data(loader.get_subjects()[-1])['gaze_data'][0]
# Out:
# "[{'event_type': 'MonocularEyeSampleEventNT', 'event_id': 332, 'logged_time': 8.378904199986643, 'system_time': 8.381759799958672, 'gaze_x_left': 113.0, 'gaze_y_left': -64.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 113.0, 'avg_gaze_y': -64.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 337, 'logged_time': 8.398904199986642, 'system_time': 8.413216699962504, 'gaze_x_left': 114.0, 'gaze_y_left': -64.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 114.0, 'avg_gaze_y': -64.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 338, 'logged_time': 8.418904199986642, 'system_time': 8.429820399964228, 'gaze_x_left': 116.0, 'gaze_y_left': -67.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 116.0, 'avg_gaze_y': -67.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 340, 'logged_time': 8.438904199986641, 'system_time': 8.446038499998394, 'gaze_x_left': 119.0, 'gaze_y_left': -73.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 119.0, 'avg_gaze_y': -73.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 342, 'logged_time': 8.458904199986641, 'system_time': 8.461889399972279, 'gaze_x_left': 128.0, 'gaze_y_left': -89.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 128.0, 'avg_gaze_y': -89.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 348, 'logged_time': 8.47890419998664, 'system_time': 8.493466899963096, 'gaze_x_left': 156.0, 'gaze_y_left': -142.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 156.0, 'avg_gaze_y': -142.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 353, 'logged_time': 8.49890419998664, 'system_time': 8.509372500004247, 'gaze_x_left': 168.0, 'gaze_y_left': -170.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 168.0, 'avg_gaze_y': -170.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 359, 'logged_time': 8.51890419998664, 'system_time': 8.525187999999616, 'gaze_x_left': 179.0, 'gaze_y_left': -191.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 179.0, 'avg_gaze_y': -191.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 363, 'logged_time': 8.53890419998664, 'system_time': 8.54068079998251, 'gaze_x_left': 184.0, 'gaze_y_left': -202.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 184.0, 'avg_gaze_y': -202.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 367, 'logged_time': 8.558904199986639, 'system_time': 8.572374999988824, 'gaze_x_left': 189.0, 'gaze_y_left': -212.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 189.0, 'avg_gaze_y': -212.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 368, 'logged_time': 8.578904199986638, 'system_time': 8.588793899980374, 'gaze_x_left': 189.0, 'gaze_y_left': -212.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 189.0, 'avg_gaze_y': -212.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 371, 'logged_time': 8.598904199986638, 'system_time': 8.613755400001537, 'gaze_x_left': 189.0, 'gaze_y_left': -213.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 189.0, 'avg_gaze_y': -213.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 401, 'logged_time': 8.878904199986632, 'system_time': 8.88549969997257, 'gaze_x_left': 154.0, 'gaze_y_left': -207.0,  ...

# %%
loader = DataLoader(config, root='../')
loader.plot_gaze(loader.get_subjects()[0], 0, gradient=True)
